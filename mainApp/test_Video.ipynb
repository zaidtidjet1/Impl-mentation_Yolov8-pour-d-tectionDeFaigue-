# %%
import cv2
from ultralytics import YOLO

model = YOLO("C:/Users/Samyak/Downloads/YOLO_Project/YOLO_Project/yolov8m.pt")

cap = cv2.VideoCapture(0)

while cap.isOpened():
    success, frame = cap.read()

    if success:
        results = model.predict(frame, imgsz=640, conf=0.5)
        annotated_frame = results[0].plot()
        cv2.imshow("Drowsy-Awake Detections", annotated_frame)

        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 2042.6ms
# Speed: 12.4ms preprocess, 2042.6ms inference, 42.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1991.9ms
# Speed: 18.5ms preprocess, 1991.9ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1306.9ms
# Speed: 4.4ms preprocess, 1306.9ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 868.2ms
# Speed: 2.7ms preprocess, 868.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1016.4ms
# Speed: 4.6ms preprocess, 1016.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 903.9ms
# Speed: 4.4ms preprocess, 903.9ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 889.3ms
# Speed: 5.1ms preprocess, 889.3ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 854.4ms
# ...

# %%
from ultralytics import YOLO
import cv2

model = YOLO('C:/Users/hp/runs/detect/train16/weights/best.pt')
             
pred=model('img1.jpg', imgsz=640, conf=0.5, show=True, save=True, verbose=False)
# Out:
# Results saved to C:\Users\hp\runs\detect\predict22

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('C:/Users/hp/Desktop/YOLO_Project/img1.jpg')
plt.imshow(img)
plt.axis('off') 
plt.show()

# %%
import cv2
from ultralytics import YOLO

model = YOLO("C:/Users/Samyak/Downloads/YOLO_Project/YOLO_Project/yolov8m.pt")

#video_path = "C:/Users/hp/Desktop/YOLO_Project/video.mp4"
video_path = "C:/Users/Samyak/Downloads/YOLO_Project/YOLO_Project/video.mp4"

cap = cv2.VideoCapture(video_path)

while cap.isOpened():
    success, frame = cap.read()

    if success:
        results = model.predict(frame, imgsz=640, conf=0.5)
        annotated_frame = results[0].plot()
        cv2.imshow("Drowsy-Awake Detections", annotated_frame)

        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 5 persons, 4 cars, 1 umbrella, 530.2ms
# Speed: 9.0ms preprocess, 530.2ms inference, 23.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 1 umbrella, 474.7ms
# Speed: 4.2ms preprocess, 474.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 1 umbrella, 460.6ms
# Speed: 1.3ms preprocess, 460.6ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 1 umbrella, 420.7ms
# Speed: 1.0ms preprocess, 420.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 1 umbrella, 425.9ms
# Speed: 1.0ms preprocess, 425.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 1 umbrella, 390.5ms
# Speed: 1.0ms preprocess, 390.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 1 umbrella, 444.5ms
# ...
